# %% [markdown]
# # Jet Tagging with Transformers
#
# This notebook shows how to use a Transformer architecture for jet classification between QCD and TT jets using anti-kt clustered particles. The transformer can capture complex interactions between particles through its self-attention mechanism.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from jet_cluster_dataloader_utils import get_dataloaders
from jet_plotting_utils import plot_confusion_matrix, plot_training_history, plot_roc_curve
from jet_utils import load_images

# %% [markdown]
# # 1 - Load data

# %% [markdown]
# We are going to use the same data as we did in the deep set. Transformers usually excel at sequential data, but that is not quite what we have here. Instead, we are using the transformer to learn a relationship between the clusters we have found in the data, quite analogous to what we had in the graph neural nets. The actual jet tagging algorithms at CERN have been tried out with all the methods you have seen so far, and transformers seem to be the best performing. You can read more about the theoretical motivation in [this paper](https://arxiv.org/html/2406.08590v1) if you're interested. Do note that we are using simpler data than they are there.

# %%
# Set data path and parameters
batch_size = 32
R = 0.4  # Jet radius parameter
pt_min = 0.1  # Minimum pT threshold
clusters_to_consider = 10
# Get dataloaders
train_loader, val_loader, test_loader = get_dataloaders(
    batch_size=batch_size,
    R=R,
    pt_min=pt_min, 
    max_clusters=clusters_to_consider
)

print(f"Number of training batches: {len(train_loader)}")
print(f"Number of validation batches: {len(val_loader)}")
print(f"Number of test batches: {len(test_loader)}")
# Out:
# Number of training batches: 110
# Number of validation batches: 16
# Number of test batches: 32

# %% [markdown]
# # 2- Define the model

# %% [markdown]
# The model is based on the one found in [the paper mentioned earlier](https://arxiv.org/html/2406.08590v1). Note that it differs from many transformers in that there is no positional encoder. In an LLM for instance, the position of a word in a sentence is quite important, whereas here the position of the jets don't matter

# %%
class Transformer(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=128, num_heads=4, num_layers=2, output_dim=1):
        super(Transformer, self).__init__()
        
        # Input projection
        self.input_proj = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(0.1)
        )
        
        # Transformer encoder layers
        # this layer implements a transformer as laid out in the paper Attention Is All You Need.
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=num_heads,
            dim_feedforward=hidden_dim * 4,
            batch_first=True,
            dropout=0.2,
            activation='gelu'  # Using GELU as in the paper
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # Global pooling and classification head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.LayerNorm(hidden_dim // 2),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim // 2, output_dim)
        )
    
    def forward(self, x):
        # x shape: [batch_size, max_clusters, input_dim]
        
        # Project input
        x = self.input_proj(x)  # Shape: [batch_size, max_clusters, hidden_dim]
        
        # Apply transformer
        x = self.transformer(x)  # Shape: [batch_size, max_clusters, hidden_dim]
        
        # Global pooling (mean over clusters)
        x = x.mean(dim=1)  # Shape: [batch_size, hidden_dim]
        
        # Classification head
        x = self.classifier(x).squeeze()  # Shape: [batch_size, output_dim]
        return x

# %% [markdown]
# # 3 - Train the model

# %% [markdown]
# If you looked at the deep set notebook, you might notice that this is the exact same training loop. If you write good code, you can make it into functions and reuse it!

# %%
# Create datasets
# Initialize model and training components
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Transformer().to(device)
class_weights = torch.tensor([1.0, 1.3]).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights[1])
optimizer = optim.Adam(model.parameters(), lr=0.001)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 
    mode='min',           # Monitor for minimum (loss)
    factor=0.1,           # Reduce LR by factor of 0.1
    patience=10,          # Wait 10 epochs before reducing
    verbose=True,         # Print when LR is reduced
    min_lr=1e-8          # Minimum learning rate
)

history = {
    'loss': [],
    'val_loss': [],
    'accuracy': [],
    'val_accuracy': [],
    'lr': [],
}

# Training loop
num_epochs = 60
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    
    for clusters, labels in train_loader:
        clusters, labels = clusters.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(clusters)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
        # Calculate accuracy
        preds = (outputs > 0.5).float()
        total += labels.size(0)
        correct += preds.eq(labels).sum().item()
    
    # Validation
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for clusters, labels in val_loader:
            clusters, labels = clusters.to(device), labels.to(device)
            outputs = model(clusters)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            
            # Calculate accuracy
            preds = (outputs > 0.5).float()
            val_total += labels.size(0)
            val_correct += preds.eq(labels).sum().item()
    
    # Calculate epoch metrics
    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_acc = 100. * correct / total
    val_acc = 100. * val_correct / val_total

    scheduler.step(val_loss)
    
    # Append to history
    history['loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    history['accuracy'].append(train_acc)
    history['val_accuracy'].append(val_acc)
    
    current_lr = optimizer.param_groups[0]['lr']
    history['lr'].append(current_lr)
    
    print(f'Epoch {epoch+1}/{num_epochs}:')
    print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
    print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    print(f'Learning Rate: {current_lr:.2e}')
# Out:
# Epoch 1/40:
# Train Loss: 0.5176, Train Acc: 81.11%
# Val Loss: 0.3414, Val Acc: 88.65%
# Learning Rate: 1.00e-03
# Epoch 2/40:
# Train Loss: 0.3791, Train Acc: 88.72%
# Val Loss: 0.3390, Val Acc: 88.05%
# Learning Rate: 1.00e-03
# Epoch 3/40:
# Train Loss: 0.3644, Train Acc: 88.75%
# Val Loss: 0.3451, Val Acc: 88.25%
# Learning Rate: 1.00e-03
# Epoch 4/40:
# Train Loss: 0.3541, Train Acc: 89.18%
# Val Loss: 0.3456, Val Acc: 89.24%
# Learning Rate: 1.00e-03
# Epoch 5/40:
# Train Loss: 0.3547, Train Acc: 89.35%
# Val Loss: 0.3486, Val Acc: 87.45%
# Learning Rate: 1.00e-03
# Epoch 6/40:
# Train Loss: 0.3431, Train Acc: 89.74%
# Val Loss: 0.3580, Val Acc: 87.05%
# Learning Rate: 1.00e-03
# Epoch 7/40:
# Train Loss: 0.3418, Train Acc: 89.57%
# Val Loss: 0.3569, Val Acc: 87.25%
# Learning Rate: 1.00e-03
# Epoch 8/40:
# Train Loss: 0.3410, Train Acc: 89.86%
# Val Loss: 0.3383, Val Acc: 88.45%
# Learning Rate: 1.00e-03
# Epoch 9/40:
# Train Loss: 0.3348, Train Acc: 89.66%
# Val Loss: 0.3412, Val Acc: 87.85%
# Learning Rate: 1.00e-03
# Epoch 10/40:
# Train Loss: 0.3408, Train Acc: 89.97%
# Val Loss: 0.3362, Val Acc: 88.45%
# Learning Rate: 1.00e-03
# Epoch 11/40:
# Train Loss: 0.3393, Train Acc: 89.63%
# Val Loss: 0.3321, Val Acc: 88.05%
# Learning Rate: 1.00e-03
# Epoch 12/40:
# Train Loss: 0.3406, Train Acc: 89.74%
# Val Loss: 0.3351, Val Acc: 87.85%
# Learning Rate: 1.00e-03
# Epoch 13/40:
# Train Loss: 0.3275, Train Acc: 90.14%
# Val Loss: 0.3412, Val Acc: 86.85%
# Learning Rate: 1.00e-03
# Epoch 14/40:
# Train Loss: 0.3253, Train Acc: 90.43%
# Val Loss: 0.3519, Val Acc: 88.65%
# Learning Rate: 1.00e-03
# Epoch 15/40:
# Train Loss: 0.3325, Train Acc: 89.77%
# Val Loss: 0.3475, Val Acc: 87.65%
# Learning Rate: 1.00e-03
# Epoch 16/40:
# Train Loss: 0.3358, Train Acc: 89.89%
# Val Loss: 0.3343, Val Acc: 85.26%
# Learning Rate: 1.00e-03
# Epoch 17/40:
# Train Loss: 0.3368, Train Acc: 89.77%
# Val Loss: 0.3380, Val Acc: 89.04%
# Learning Rate: 1.00e-03
# Epoch 18/40:
# Train Loss: 0.3287, Train Acc: 89.89%
# Val Loss: 0.3371, Val Acc: 88.45%
# Learning Rate: 1.00e-03
# Epoch 19/40:
# Train Loss: 0.3344, Train Acc: 89.83%
# Val Loss: 0.3815, Val Acc: 88.65%
# Learning Rate: 1.00e-03
# Epoch 20/40:
# Train Loss: 0.3422, Train Acc: 90.06%
# Val Loss: 0.3708, Val Acc: 87.25%
# Learning Rate: 1.00e-03
# Epoch 21/40:
# Train Loss: 0.3263, Train Acc: 90.43%
# Val Loss: 0.3805, Val Acc: 87.85%
# Learning Rate: 1.00e-03
# Epoch 22/40:
# Train Loss: 0.3355, Train Acc: 89.91%
# Val Loss: 0.4128, Val Acc: 88.84%
# Learning Rate: 1.00e-04
# Epoch 23/40:
# Train Loss: 0.3358, Train Acc: 90.28%
# Val Loss: 0.3381, Val Acc: 88.84%
# Learning Rate: 1.00e-04
# Epoch 24/40:
# Train Loss: 0.3195, Train Acc: 90.28%
# Val Loss: 0.3419, Val Acc: 88.65%
# Learning Rate: 1.00e-04
# Epoch 25/40:
# Train Loss: 0.3173, Train Acc: 90.51%
# Val Loss: 0.3395, Val Acc: 88.45%
# Learning Rate: 1.00e-04
# Epoch 26/40:
# Train Loss: 0.3196, Train Acc: 90.23%
# Val Loss: 0.3383, Val Acc: 88.25%
# Learning Rate: 1.00e-04
# Epoch 27/40:
# Train Loss: 0.3163, Train Acc: 90.68%
# Val Loss: 0.3394, Val Acc: 88.05%
# Learning Rate: 1.00e-04
# Epoch 28/40:
# Train Loss: 0.3132, Train Acc: 90.45%
# Val Loss: 0.3402, Val Acc: 87.85%
# Learning Rate: 1.00e-04
# Epoch 29/40:
# Train Loss: 0.3183, Train Acc: 90.09%
# Val Loss: 0.3398, Val Acc: 88.25%
# Learning Rate: 1.00e-04
# Epoch 30/40:
# Train Loss: 0.3142, Train Acc: 90.91%
# Val Loss: 0.3353, Val Acc: 87.45%
# Learning Rate: 1.00e-04
# Epoch 31/40:
# Train Loss: 0.3145, Train Acc: 90.54%
# Val Loss: 0.3344, Val Acc: 88.45%
# Learning Rate: 1.00e-04
# Epoch 32/40:
# Train Loss: 0.3165, Train Acc: 90.37%
# Val Loss: 0.3360, Val Acc: 87.85%
# Learning Rate: 1.00e-04
# Epoch 33/40:
# Train Loss: 0.3152, Train Acc: 90.80%
# Val Loss: 0.3419, Val Acc: 88.65%
# Learning Rate: 1.00e-05
# Epoch 34/40:
# Train Loss: 0.3094, Train Acc: 90.54%
# Val Loss: 0.3411, Val Acc: 88.65%
# Learning Rate: 1.00e-05
# Epoch 35/40:
# Train Loss: 0.3146, Train Acc: 90.65%
# Val Loss: 0.3401, Val Acc: 88.65%
# Learning Rate: 1.00e-05
# Epoch 36/40:
# Train Loss: 0.3115, Train Acc: 90.57%
# Val Loss: 0.3393, Val Acc: 88.65%
# Learning Rate: 1.00e-05
# Epoch 37/40:
# Train Loss: 0.3138, Train Acc: 90.80%
# Val Loss: 0.3394, Val Acc: 88.25%
# Learning Rate: 1.00e-05
# Epoch 38/40:
# Train Loss: 0.3115, Train Acc: 90.94%
# Val Loss: 0.3395, Val Acc: 88.45%
# Learning Rate: 1.00e-05
# Epoch 39/40:
# Train Loss: 0.3125, Train Acc: 90.82%
# Val Loss: 0.3390, Val Acc: 88.45%
# Learning Rate: 1.00e-05
# Epoch 40/40:
# Train Loss: 0.3143, Train Acc: 90.68%
# Val Loss: 0.3383, Val Acc: 88.45%
# Learning Rate: 1.00e-05

# %%
plot_training_history(history, metrics=['loss', 'accuracy'])

# %% [markdown]
# # 4 - Evaluating performance

# %%
model.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for clusters, labels in val_loader:  # Changed 'masks' to 'mask' to match dataset output
        clusters, labels = clusters.to(device), labels.to(device)  # Move mask to device too
        outputs = torch.sigmoid(model(clusters))  #Our output was logits, so we do sigmoid to get the probabilities
        
        all_preds.extend(outputs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

all_preds_discrete = np.where(np.array(all_preds) > 0.5, 1, 0)
# Calculate accuracy
accuracy = np.mean(np.array(all_labels) == np.array(all_preds_discrete))
print(f'Test Accuracy: {accuracy:.4f}')

# Plot confusion matrix
plot_confusion_matrix(all_labels, all_preds_discrete)
# Out:
# Test Accuracy: 0.8884

# %%
model.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for clusters, labels in val_loader:  # Changed 'masks' to 'mask' to match dataset output
        clusters, labels = clusters.to(device), labels.to(device)  # Move mask to device too
        outputs = torch.sigmoid(model(clusters))  #Our output was logits, so we do sigmoid to get the probabilities
        
        all_preds.extend(outputs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

all_preds_discrete = np.where(np.array(all_preds) > 0.5, 1, 0)
# Calculate accuracy
accuracy = np.mean(np.array(all_labels) == np.array(all_preds_discrete))
print(f'Test Accuracy: {accuracy:.4f}')

# Plot confusion matrix
plot_confusion_matrix(all_labels, all_preds_discrete)
# Out:
# Test Accuracy: 0.8845

# %%
plot_roc_curve(all_labels, all_preds)

# %% [markdown]
# # 5 - Make predictions

# %%
y_pred_test = []
for data in test_loader:
    data = data[0]
    with torch.no_grad():
        output = model(data.to(device))
        # could you change the prediction threshold? Would that make it better?
        prediction = torch.sigmoid(output).numpy()
        y_pred_test.extend(prediction)

# %%
import pandas as pd

# this is a very lazy way to get the test_ids, the data hasn't been shuffled,so they'll be in 
# the same order. In a real example, we'd change the dataloader to also give our test_ids
X_train, y_train, train_ids, X_val_, y_val, val_ids, X_test, test_ids = load_images()


solution = pd.DataFrame({'id':test_ids, 'label':y_pred_test})
solution.to_csv('submission.csv', index=False)
